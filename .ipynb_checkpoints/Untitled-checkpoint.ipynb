# %%
import requests

# %%
import requests

header =  {'Accept': 'application/json, text/plain, */*',
                   'Accept-Encoding': 'gzip, deflate, br',
                   'Accept-Language': 'vi-VN,vi;q=0.9,en-US;q=0.8,en;q=0.7',
                   'Connection': 'keep-alive',
                   'Content-Length': '0',
                   'Cookie': '_ga=GA1.3.1846747131.1598840350; _gid=GA1.3.1601226693.1598840350',
                   'Host': 'apiquantri.vinaphoneplus.com.vn',
                   'Origin': 'https://vinaphoneplus.com.vn',
                   'Referer': 'https://vinaphoneplus.com.vn/',
                   'Sec-Fetch-Dest': 'empty',
                   'Sec-Fetch-Mode': 'cors',
                   'Sec-Fetch-Site': 'same-site',
                   'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36', }

# %%
with open('range(20000,27000).txt','a+') as f:
    for i in range(20000,27000):
        response = requests.get('https://apiquantri.vinaphoneplus.com.vn/api/APIForWebApp/Api_XemThongTinChuongTrinhUuDai?CTUuDaiId={}&Token='.format(i),verify = False)
    f.write(response.context)
    f.write(i)
# Out:
# /home/nero/anaconda3/envs/text/lib/python3.7/site-packages/urllib3/connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'apiquantri.vinaphoneplus.com.vn'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /home/nero/anaconda3/envs/text/lib/python3.7/site-packages/urllib3/connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'apiquantri.vinaphoneplus.com.vn'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ...
